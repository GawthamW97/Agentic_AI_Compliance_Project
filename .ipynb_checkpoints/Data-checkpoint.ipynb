# %%
import pandas as pd

# %%
def build_hierarchy(row):
    return f"Section {row['section']} - Chapter - {str(row["hscode"]).strip("'")[:2]} - {row['description']}"

# %%
df = pd.read_csv("./dataset/harmonized-system.csv")
df["text"] = df.apply(build_hierarchy,axis=1)
df.value_counts("text")
# Out:
# text
# Section TOTAL - Chapter - 99 - Commodities not specified according to kind                                                                                                                                                                                                                     3
# Section VI - Chapter - 38 - Mixtures containing halogenated derivatives of methane, ethane or propane; containing other hydrofluorocarbons (HFCs) but not containing chlorofluorocarbons (CFCs) or hydrochlorofluorocarbons (HCFCs); other mixtures, not included in the subheadings above,    3
# Section XI - Chapter - 58 - Fabrics, woven; of metal thread and metallised yarn of heading no. 5605, of a kind used in apparel, as furnishing fabrics or similar purposes; n.e.c. or included                                                                                                  2
# Section XV - Chapter - 78 - Lead; articles n.e.c. in chapter 78                                                                                                                                                                                                                                2
# Section XV - Chapter - 79 - Zinc; articles n.e.c. in chapter 79                                                                                                                                                                                                                                2
#                                                                                                                                                                                                                                                                                               ..
# Section VI - Chapter - 31 - Fertilizers, mineral or chemical; phosphatic, superphosphates, other than containing by weight 35% or more of diphosphorus pentaoxide (P2O5)                                                                                                                       1
# Section VI - Chapter - 31 - Fertilizers, mineral or chemical; phosphatic, superphosphates, containing by weight 35% or more of diphosphorus pentaoxide (P2O5)                                                                                                                                  1
# Section VI - Chapter - 31 - Fertilizers, mineral or chemical; phosphatic, n.e.c. in heading no. 3103                                                                                                                                                                                           1
# Section VI - Chapter - 31 - Fertilizers, mineral or chemical; nitrogenous, urea, whether or not in aqueous solution                                                                                                                                                                            1
# Section XXI - Chapter - 97 - Works of art; collectors' pieces and antiques                                                                                                                                                                                                                     1
# Name: count, Length: 6747, dtype: int64
