# %%
import pandas as pd

# %%
# def build_hierarchy(row):
#     return f"Section {row['section']} - Chapter - {str(row["hscode"]).strip("'")[:2]} - {row['description']}"
# Out:
#   Cell In[6], line 2
#     return f"Section {row['section']} - Chapter - {str(row["hscode"]).strip("'")[:2]} - {row['description']}"
#                                                                                                          ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
df = pd.read_csv("./dataset/harmonized-system.csv")
# df["text"] = df.apply(build_hierarchy,axis=1)
# df.value_counts("text")

# %%
# df = pd.read_csv("./dataset/hs_code_data.csv")
# df = df.drop_duplicates(["comm_code"])

# %%
df.head()
# Out:
#   section  hscode                                        description parent  \
# 0       I       1                                      Animals; live  TOTAL
# 1       I     101             Horses, asses, mules and hinnies; live      1
# 2       I   10121           Horses; live, pure-bred breeding animals    101
# 3       I   10129  Horses; live, other than pure-bred breeding an...    101
# 4       I   10130                                        Asses; live    101
#
#    level
# 0      2
# 1      4
# 2      6
# 3      6
# 4      6

# %%
# select only six digit HS Codes
df["hscode"] = df["hscode"].astype(str)
df = df[df["hscode"].str.len() >= 5]
df = df.sample(n=1000, random_state=42)
df_final = df[["hscode","description"]]
df_final.to_csv("test_hs_codes.csv", encoding='utf-8', index=False, header=["hscode", "description"])

# %%
# df["hscode"] = df["comm_code"].astype('string')
# df["description"] = df["commodity"]

# %%
# # 1. First, make sure your column is the string data type
# df['hscode'] = df['hscode'].astype(str)

# # 2. Use .str.zfill() to pad each string to a length of 6
# df['hscode'] = df['hscode'].str.zfill(6)

# # Now check the result
# print(df['hscode'])

# %%
# df_final = df[["hscode","description"]]
# df_final.to_csv("test_hs_codes.csv", encoding='utf-8', index=False, header=["hscode", "description"])

# %%
df_test = pd.read_csv("./dataset/test_hs_codes.csv")
df_test["hscode"] = df_test["hscode"].astype('string')

# %%
code_dict = df_test["hscode"].to_dict()
print(code_dict)
# Out:
# {0: '1', 1: '1', 2: '101', 3: '10110', 4: '10111', 5: '10119', 6: '10120', 7: '10121', 8: '10129', 9: '10130', 10: '10190', 11: '102', 12: '10210', 13: '10221', 14: '10229', 15: '10231', 16: '10239', 17: '10290', 18: '103', 19: '10310', 20: '10391', 21: '10392', 22: '104', 23: '10410', 24: '10420', 25: '105', 26: '10511', 27: '10512', 28: '10513', 29: '10514', 30: '10515', 31: '10519', 32: '10591', 33: '10592', 34: '10593', 35: '10594', 36: '10599', 37: '106', 38: '10600', 39: '10611', 40: '10612', 41: '10613', 42: '10614', 43: '10619', 44: '10620', 45: '10631', 46: '10632', 47: '10633', 48: '10639', 49: '10641', 50: '10649', 51: '10690', 52: '2', 53: '201', 54: '20110', 55: '20120', 56: '20130', 57: '202', 58: '20210', 59: '20220', 60: '20230', 61: '203', 62: '20311', 63: '20312', 64: '20319', 65: '20321', 66: '20322', 67: '20329', 68: '204', 69: '20410', 70: '20421', 71: '20422', 72: '20423', 73: '20430', 74: '20441', 75: '20442', 76: '20443', 77: '20450', 78: '205', 79: '20500', 80: '206', 81: '20610', 82: '20621', 83: '20622', 84: '20629', 85: '20630', 86: '20641', 87: '20649', 88: '20680', 89: '20690', 90: '207', 91: '20710', 92
# Now you can inspect your DataFrame
df_test.head()
# Out:
#     OEC ID     HS ID Product Level  \
# 0        1         1       Section
# 1      101        01           HS2
# 2    10101     01.01           HS4
# 3  1010110  01.01.10           HS6
# 4  1010111  01.01.11           HS6
#
#                                         Product Name  \
# 0                                    Animal Products
# 1                                       Live animals
# 2                                             Horses
# 3  Live horses/asses/mules/hinnies: pure-bred bre...
# 4                          Pure-bred Breeding Horses
#
#                              Revision
# 0  HS92,HS96,HS02,HS07,HS12,HS17,HS22
# 1  HS92,HS96,HS02,HS07,HS12,HS17,HS22
# 2  HS92,HS96,HS02,HS07,HS12,HS17,HS22
# 3                           HS02,HS07
# 4                           HS92,HS96

# %%
df_test["hscode"] = df_test["HS ID"].str.replace('.', '')
df_test["description"] = df_test["Product Name"]

# %%
df_test
# Out:
#         OEC ID     HS ID Product Level  \
# 0            1         1       Section
# 1          101        01           HS2
# 2        10101     01.01           HS4
# 3      1010110  01.01.10           HS6
# 4      1010111  01.01.11           HS6
# ...        ...       ...           ...
# 8278  21970690  97.06.90           HS6
# 8279        22        22       Section
# 8280      2299        99           HS2
# 8281    229999     99.99           HS4
# 8282  22999999  99.99.99           HS6
#
#                                            Product Name  \
# 0                                       Animal Products
# 1                                          Live animals
# 2                                                Horses
# 3     Live horses/asses/mules/hinnies: pure-bred bre...
# 4                             Pure-bred Breeding Horses
# ...                                                 ...
# 8278                     Antiques >100 years ≤250 years
# 8279                                        Unspecified
# 8280                                       Unclassified
# 8281                Commodities not elsewhere specified
# 8282        Commodities not specified according to kind
#
#                                 Revision  hscode  \
# 0     HS92,HS96,HS02,HS07,HS12,HS17,HS22       1
# 1     HS92,HS96,HS02,HS07,HS12,HS17,HS22      01
# 2     HS92,HS96,HS02,HS07,HS12,HS17,HS22    0101
# 3                              HS02,HS07  010110
# 4                              HS92,HS96  010111
# ...                                  ...     ...
# 8278                                HS22  970690
# 8279                                 NaN      22
# 8280                                 NaN      99
# 8281                                 NaN    9999
# 8282                                 NaN  999999
#
#                                             description
# 0                                       Animal Products
# 1                                          Live animals
# 2                                                Horses
# 3     Live horses/asses/mules/hinnies: pure-bred bre...
# 4                             Pure-bred Breeding Horses
# ...                                                 ...
# 8278                     Antiques >100 years ≤250 years
# 8279                                        Unspecified
# 8280                                       Unclassified
# 8281                Commodities not elsewhere specified
# 8282        Commodities not specified according to kind
#
# [8283 rows x 7 columns]

# %%
# # 1. First, make sure your column is the string data type
# df_test['hscode'] = df_test['hscode'].astype(str)

# # 2. Use .str.zfill() to pad each string to a length of 6
# df_test['hscode'] = df_test['hscode'].str.zfill(6)

# # Now check the result
# # print(df_test['hscode'])
# df_test['hscode']

# %%
# test_df, eval_df = train_test_split(df_test, test_size=0.5, random_state=42)

# %%
df_test["hscode"] = df_test["hscode"].astype(str)
df_test = df_test[df_test["hscode"].str.len() >= 5]
df["hscode"] = df["hscode"].astype("int64")
df_test["hscode"] = df_test["hscode"].astype("int64")
matches = df_test[df_test["hscode"].isin(df["hscode"])]
print(matches)
matches = matches.sample(n=1000, random_state=42)
df_test_final = matches[["hscode","description"]]
df_test_final.to_csv("test_ext_hs_codes.csv", encoding='utf-8', index=False, header=["hscode", "description"])
# Out:
#         OEC ID     HS ID Product Level  \
# 7      1010121  01.01.21           HS6
# 8      1010129  01.01.29           HS6
# 9      1010130  01.01.30           HS6
# 10     1010190  01.01.90           HS6
# 13     1010221  01.02.21           HS6
# ...        ...       ...           ...
# 8273  21970531  97.05.31           HS6
# 8274  21970539  97.05.39           HS6
# 8277  21970610  97.06.10           HS6
# 8278  21970690  97.06.90           HS6
# 8282  22999999  99.99.99           HS6
#
#                                            Product Name  \
# 7              Horses: live, pure-bred breeding animals
# 8     Horses: live, other than pure-bred breeding an...
# 9                                           Asses: live
# 10                              Mules and hinnies: live
# 13             Cattle: live, pure-bred breeding animals
# ...                                                 ...
# 8273           Numismatic collectors' pieces >100 years
# 8274           Numismatic collectors' pieces ≤100 years
# 8277                                Antiques >250 years
# 8278                     Antiques >100 years ≤250 years
# 8282        Commodities not specified according to kind
#
#                       Revision  hscode  \
# 7               HS12,HS17,HS22   10121
# 8               HS12,HS17,HS22   10129
# 9               HS12,HS17,HS22   10130
# 10    HS02,HS07,HS12,HS17,HS22   10190
# 13              HS12,HS17,HS22   10221
# ...                        ...     ...
# 8273                      HS22  970531
# 8274                      HS22  970539
# 8277                      HS22  970610
# 8278                      HS22  970690
# 8282                       NaN  999999
#
#                                             description
# 7              Horses: live, pure-bred breeding animals
# 8     Horses: live, other than pure-bred breeding an...
# 9                                           Asses: live
# 10                              Mules and hinnies: live
# 13             Cattle: live, pure-bred breeding animals
# ...                                                 ...
# 8273           Numismatic collectors' pieces >100 years
# 8274           Numismatic collectors' pieces ≤100 years
# 8277                                Antiques >250 years
# 8278                     Antiques >100 years ≤250 years
# 8282        Commodities not specified according to kind
#
# [5613 rows x 7 columns]

# %%
# df_final = eval_df[["hscode","description"]]
# df_final.to_csv("eval_hs_codes.csv", encoding='utf-8', index=False, header=["hscode", "description"])

# %%
df_train = pd.read_csv('./dataset/harmonized-system.csv')
df_train
# Out:
#      section  hscode                                        description  \
# 0          I       1                                      Animals; live
# 1          I     101             Horses, asses, mules and hinnies; live
# 2          I   10121           Horses; live, pure-bred breeding animals
# 3          I   10129  Horses; live, other than pure-bred breeding an...
# 4          I   10130                                        Asses; live
# ...      ...     ...                                                ...
# 6935     XXI  970690  Antiques; of an age exceeding 100 years but no...
# 6936   TOTAL      99        Commodities not specified according to kind
# 6937   TOTAL    9999        Commodities not specified according to kind
# 6938   TOTAL  999999        Commodities not specified according to kind
# 6939   TOTAL   TOTAL                    Total of all HS2022 commodities
#
#      parent  level
# 0     TOTAL      2
# 1         1      4
# 2       101      6
# 3       101      6
# 4       101      6
# ...     ...    ...
# 6935   9706      6
# 6936  TOTAL      2
# 6937     99      4
# 6938   9999      6
# 6939  TOTAL      5
#
# [6940 rows x 5 columns]

# %%
df_train["hscode"].head(20)
# Out:
# 0         1
# 1       101
# 2     10121
# 3     10129
# 4     10130
# 5     10190
# 6       102
# 7     10221
# 8     10229
# 9     10231
# 10    10239
# 11    10290
# 12      103
# 13    10310
# 14    10391
# 15    10392
# 16      104
# 17    10410
# 18    10420
# 19      105
# Name: hscode, dtype: object

# %%
df_test["hscode"].astype("int32").head(20)
# Out:
# 0         1
# 1         1
# 2       101
# 3     10110
# 4     10111
# 5     10119
# 6     10120
# 7     10121
# 8     10129
# 9     10130
# 10    10190
# 11      102
# 12    10210
# 13    10221
# 14    10229
# 15    10231
# 16    10239
# 17    10290
# 18      103
# 19    10310
# Name: hscode, dtype: int32

# %%
df_train = df_train[df_train["hscode"].values != "TOTAL"]
df_train["hscode"] = df_train["hscode"].astype("int")
code_list=[]
for idx,row in df_test.iterrows():
    if(int(row["hscode"]) in df_train["hscode"].values):
        record = {"hscode":int(row["hscode"]),"description":row["description"]}
        code_list.append(record)
df_final = pd.DataFrame.from_records(code_list) 
df_final
df_final.to_csv("test_hs_codes.csv", encoding='utf-8', index=False, header=["hscode", "description"])

# %%
df_01 = pd.read_csv('./dataset/harmonized-system - Copy.csv')
df_02 = pd.read_csv('./dataset/test_ext_hs_codes.csv')

# %%
df_01.value_counts("hscode")
# Out:
# hscode
# 0         1
# 620719    1
# 620891    1
# 620829    1
# 620822    1
#          ..
# 251110    1
# 251020    1
# 251010    1
# 250900    1
# 999999    1
# Name: count, Length: 6940, dtype: int64

# %%
df_02.value_counts("hscode")
# Out:
# hscode
# 10290     1
# 721899    1
# 720529    1
# 720719    1
# 720838    1
#          ..
# 300640    1
# 300660    1
# 300670    1
# 300692    1
# 970539    1
# Name: count, Length: 1000, dtype: int64

# %%
# count = 0
# for _, row in df_02.iterrows():
#     if row["hscode"] in df_01["hscode"]:
#         count += 1
# print(count)
df_01["hscode"] = df_01["hscode"].astype("int64")
df_02["hscode"] = df_02["hscode"].astype("int64")
matches = df_02[df_02["hscode"].isin(df_01["hscode"])]
print(matches)
# Out:
#      hscode                                        description
# 0    820110                                 Spades and shovels
# 1    720851    Iron/Steel Sheets: Very Thick, Hot-Rolled, Wide
# 2     20753  Meat and edible offal: of geese, fatty livers ...
# 3    843131           Parts of lifts, skip hoist or escalators
# 4    540823  Woven fabric >85% artif filament/strip, yarn d...
# ..      ...                                                ...
# 995  293159          Other halogenated phosphorous derivatives
# 996  903033  Voltage, Current, Resistance & Power Measuring...
# 997  270300                       Peat (including peat litter)
# 998  820520                   Hammers including sledge hammers
# 999  880230  Fixed wing aircraft, unladen weight 2,000-15,0...
#
# [1000 rows x 2 columns]

# %%
df_02
# Out:
#      hscode                                        description
# 0    440920  Non-conifer wood continuously shaped along any...
# 1    401022  V-Shaped Rubber Transmission Belts (180-240cm ...
# 2    850211           Generating sets, diesel, output < 75 kVA
# 3    850530                     Electro-magnetic lifting heads
# 4    580126              Chenille cotton fabric, width > 30 cm
# ..      ...                                                ...
# 995  750110                                      Nickel mattes
# 996   30361  Swordfish (Xiphias gladius), frozen (excl. fil...
# 997  841590                         Parts for air conditioners
# 998  820320        Pliers, pincers, tweezers and similar tools
# 999  293369  Heterocyclic compds with an unfused triazine r...
#
# [1000 rows x 2 columns]
