# %%
import pandas as pd

# %%
# !pip install ftfy

# %%
def readCNCodes():
    cnCodes_df = pd.read_csv("../dataset/tax_codes.csv")
    # Remove spaces from tax_code
    cnCodes_df["tax_code"] = cnCodes_df["tax_code"].str.replace(' ', '')

    # Filter rows where tax_code length is 8
    return cnCodes_df[cnCodes_df["tax_code"].str.len() == 8]

df = readCNCodes()

df.count()
# Out:
# tax_code       10255
# description    10255
# dtype: int64

# %%
df.head()
# Out:
# 0        8901
# 1      890110
# 2    89011010
# 3      890120
# 4    89012010
# Name: tax_code, dtype: object

# %% [markdown]
# # VAT Dataset

# %%
vat_df = pd.read_csv("../dataset/VAT Rates in Europe  EU VAT Rates by Country.csv")
vat_df.head(20)
# Out:
#                 Country Super-Reduced Rate (%) Reduced Rate (%)  \
# 0          Austria (AT)                      -          10 / 13
# 1          Belgium (BE)                      -           6 / 12
# 2         Bulgaria (BG)                      -                9
# 3          Croatia (HR)                      -           5 / 13
# 4           Cyprus (CY)                      -            5 / 9
# 5   Czech Republic (CZ)                      -               12
# 6          Denmark (DK)                      -                -
# 7          Estonia (EE)                      -           9 / 13
# 8          Finland (FI)                      -           10 /14
# 9           France (FR)                    2.1         5.5 / 10
# 10         Georgia (GE)                      -                -
# 11         Germany (DE)                      -                7
# 12          Greece (GR)                      -           6 / 13
# 13         Hungary (HU)                      -           5 / 18
# ...

# %%
# vat_df.value_counts("Parking Rate (%)")

# %%
vat_df.value_counts("Standard Rate (%)")
# Out:
# Standard Rate (%)
# 20.0    7
# 21.0    6
# 23.0    4
# 25.0    4
# 19.0    3
# 22.0    3
# 18.0    2
# 24.0    2
# 8.1     1
# 17.0    1
# 25.5    1
# 27.0    1
# Name: count, dtype: int64

# %%
# vat_df.value_counts("Reduced Rate (%)")

# %%
# vat_df.value_counts("Super-Reduced Rate (%)")

# %%
vat_df = vat_df["Standard Rate (%)"]
vat_df.head()
# Out:
# 0    20.0
# 1    21.0
# 2    20.0
# 3    25.0
# 4    19.0
# Name: Standard Rate (%), dtype: float64

# %% [markdown]
# # Sales Dataset

# %%
sales_df = pd.read_excel("../dataset/Online Retail.xlsx")
sales_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# sales_df.value_counts("Country")

# %%
# sales_df_uk = sales_df[sales_df["Country"] == "United Kingdom"]
# sales_df_other = sales_df[sales_df["Country"] != "United Kingdom"]

# %%
# sales_df_uk_sampled = sales_df_uk.sample(frac=0.02, random_state = 42)

# sales_df = pd.concat([sales_df_uk_sampled,sales_df_other],ignore_index=True)

# %%
# sales_df.value_counts("Country")

# %%
# sales_df.head()

# %%
# sales_df.to_csv("../dataset/Online Retail Balanced.csv")

# %%
# sales_df = pd.read_csv("../dataset/Online Retail Balanced.csv")
# sales_df.value_counts("Country")

# %%
# flipkart_df = pd.read_csv("../dataset/flipkart_com-ecommerce_sample.csv")
# flipkart_df.head()

# %%
# flipkart_df_final= flipkart_df[["uniq_id","product_name","product_category_tree","retail_price","discounted_price","description"]]
# flipkart_df_final.head()
